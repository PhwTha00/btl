# %% [markdown]
# <a href="https://colab.research.google.com/github/PhwTha00/btl/blob/main/btl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Các thư viện cần dùng

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Đọc dữ liệu

# %%
file_path = 'https://raw.githubusercontent.com/PhwTha00/btl/main/city_day.csv'
data = pd.read_csv(file_path)
print(data)
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
selected_cities = ['Amaravati', 'Delhi', 'Hyderabad']
filtered_data = data[data['City'].isin(selected_cities)].copy()

filtered_data['Date'] = pd.to_datetime(filtered_data['Date'])

start_date = pd.to_datetime('2018-01-01')
end_date = pd.to_datetime('2020-06-30')
filtered_data = filtered_data[(filtered_data['Date'] >= start_date) & (filtered_data['Date'] <= end_date)].copy()  # Tạo một bản sao để tránh cảnh báo

filtered_data.dropna(inplace=True)
filtered_data.to_csv('filtered_city_data.csv', index=False)

# %%
df = pd.read_csv('filtered_city_data.csv')
print(df)
# Out:
#            City        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     Amaravati  2018-01-01  59.03  108.83  3.45  23.36  15.23  18.03  0.09
# 1     Amaravati  2018-01-02  61.88  109.82  3.87  23.14  15.45  19.57  0.09
# 2     Amaravati  2018-01-03  71.57  137.48  5.01  39.99  25.36  25.61  0.09
# 3     Amaravati  2018-01-04  92.44  174.75  5.84  53.79  33.36  19.45  0.11
# 4     Amaravati  2018-01-05  92.90  162.69  6.38  56.39  35.19  21.02  0.08
# ...         ...         ...    ...     ...   ...    ...    ...    ...   ...
# 2428  Hyderabad  2020-06-26  27.05   54.96  5.71  21.78  14.59   9.63  0.34
# 2429  Hyderabad  2020-06-27  23.29   44.20  6.38  22.64  15.39   9.34  0.36
# 2430  Hyderabad  2020-06-28  15.80   32.18  5.79  22.73  14.89  11.09  0.36
# 2431  Hyderabad  2020-06-29  20.24   44.74  3.96  27.59  17.09  13.09  0.38
# 2432  Hyderabad  2020-06-30  19.38   41.95  2.63  24.58  14.59  10.80  0.39
#
# ...

# %% [markdown]
# **2. Khám phá và trực quan hóa dữ liệu**

# %% [markdown]
# 2.1. Biểu đồ đường PM2.5

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['PM2.5'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ PM2.5 của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('PM2.5')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.2. Biểu đồ đường PM10

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['PM10'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ PM10 của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('PM10')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.3. Biểu đồ đường NO

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['NO'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ NO của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('NO')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.4. Biểu đồ đường NO2

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['NO2'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ NO2 của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('NO2')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.5. Biểu đồ đường NOx

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['NOx'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ NOx của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('NOx')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.6. Biểu đồ đường NH3

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['NH3'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ NH3 của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('NH3')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.7. Biểu đồ đường CO

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['CO'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ CO của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('CO')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.8.Biểu đồ đường SO2

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['SO2'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ SO2 của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('SO2')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.9. Biểu đồ đường O3

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['O3'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ O3 của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('O3')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.10. Biểu đồ đường Benzene

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['Benzene'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ Benzene của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('Benzene')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.11. Biểu đồ đường Toluene

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['Toluene'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ Toluene của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('Toluene')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.12. Biểu đồ đường Xylene

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['Xylene'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ Xylene của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('Xylene')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.13. Biểu đồ đường AQI

# %%
plt.figure(figsize=(10, 6))

for city in selected_cities:
    city_data = filtered_data[filtered_data['City'] == city]
    plt.plot(city_data['Date'], city_data['AQI'], marker='o', linestyle='-', label=city)

plt.title('Biểu đồ AQI của Amaravati, Delhi và Hyderabad')
plt.xlabel('Thời gian')
plt.ylabel('AQI')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.14. Biểu đồ tròn AQI-Bucket

# %%
amaravati_data = df[df['City'] == 'Amaravati']
amaravati_aqi_distribution = amaravati_data['AQI_Bucket'].value_counts(normalize=True)

plt.figure(figsize=(8, 8))
plt.pie(amaravati_aqi_distribution, labels=amaravati_aqi_distribution.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral', 'lightgreen'])
plt.title('Phân phối AQI_Bucket trong Amaravati')
plt.show()

# %%
delhi_data = df[df['City'] == 'Delhi']
delhi_aqi_distribution = delhi_data['AQI_Bucket'].value_counts(normalize=True)

plt.figure(figsize=(8, 8))
plt.pie(delhi_aqi_distribution, labels=delhi_aqi_distribution.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral', 'lightgreen'])
plt.title('Phân phối AQI_Bucket trong Delhi')
plt.show()

# %%
hyderabad_data = df[df['City'] == 'Hyderabad']
hyderabad_aqi_distribution = hyderabad_data['AQI_Bucket'].value_counts(normalize=True)

plt.figure(figsize=(8, 8))
plt.pie(hyderabad_aqi_distribution, labels=hyderabad_aqi_distribution.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral', 'lightgreen'])
plt.title('Phân phối AQI_Bucket trong Hyderabad')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.countplot(x='AQI_Bucket', hue='City', data=filtered_data, palette='viridis')
plt.title('Biểu đồ AQI_Bucket của Amaravati, Delhi và Hyderabad')
plt.xlabel('Phân loại AQI')
plt.ylabel('Số lượng')
plt.legend(title='Thành phố')
plt.show()

# %% [markdown]
# **3. Phân tích dữ liệu**

# %% [markdown]
# *Ma trận tương quan giữa các chất gây ô nhiễm*

# %%
correlation_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Ma trận tương quan giữa các biến')
plt.show()

# %% [markdown]
# **4. Mô hình dự đoán**

# %% [markdown]
# Xác định yếu tố quan trọng gây ra ô nhiễm không khí

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

X = df.drop(['City', 'Date', 'AQI', 'AQI_Bucket'], axis=1)
y = df['AQI']
model = RandomForestRegressor()

rfe = RFE(model, n_features_to_select=1)
fit = rfe.fit(X, y)

ranking = list(fit.ranking_)
features = list(X.columns)

sorted_features = [feature for _, feature in sorted(zip(ranking, features))]

plt.figure(figsize=(10, 6))
plt.barh(sorted_features, ranking)
plt.xlabel('Ranking')
plt.title('Xác định yếu tố quan trọng gây ra ô nhiễm không khí')
plt.show()

# %% [markdown]
# 4a. Dự báo chuỗi thời gian

# %% [markdown]
# **ARIMA**

# %%
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA

def get_metrics(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "MAPE": mean_absolute_percentage_error(y_true, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_true, y_pred)),
        "MAE": mean_absolute_error(y_true, y_pred)
    }


def get_best_model(list_orders, data):
    dict_models = {}
    for idx, order in enumerate(list_orders):
        model = ARIMA(data, order=order)
        model_fit = model.fit()
        dict_models[idx] = [model, order, model_fit, model_fit.bic]
    list_models = sorted(dict_models.values(), key=lambda x: x[3])
    return list_models[0]

unique_cities = df['City'].unique()

for city in unique_cities:
    city_data = df[df['City'] == city]

    dataset = city_data['AQI'].values

    size_dataset = len(dataset)
    train, test = dataset[:size_dataset-10], dataset[size_dataset-10:]

    list_orders = [(3, 1, 5), (2, 1, 4), (1, 1, 5), (2, 1, 3)]

    model = get_best_model(list_orders, train)
    print(f"City: {city}, AIC: {model[2].aic}, BIC: {model[2].bic}, Parameters: {model[2].params}")

    y_pred = model[2].predict(start=len(train), end=len(train) + len(test) - 1, dynamic=False)
    print(get_metrics(test, y_pred))
# Out:
# City: Amaravati, AIC: 5524.206239246376, BIC: 5550.56778377008, Parameters: [-8.66546175e-02  3.15268427e-01 -8.66491596e-02 -5.08199847e-01
#  -1.29622787e-01  5.89933975e+02]
# {'R2': -1.7681429893882958, 'MAPE': 0.1375750478966265, 'RMSE': 8.587393623056078, 'MAE': 7.4304191091987235}
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# City: Delhi, AIC: 9458.815106628526, BIC: 9487.636138174177, Parameters: [-3.45091145e-01  4.66662765e-01  3.55523146e-01 -7.65165321e-01
#  -3.08547400e-01  2.09298735e+03]
# {'R2': -0.24173198737080548, 'MAPE': 0.4614579546668038, 'RMSE': 54.765677593684934, 'MAE': 50.84610977375174}
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %% [markdown]
# **Random Forest Regression**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import mean_absolute_error

df = pd.read_csv("filtered_city_data.csv")
city_data = df[df['City'] == 'Amaravati']

features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
target = 'AQI'

train, test = train_test_split(city_data, test_size=0.2, shuffle=False)

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(train[features], train[target])

y_pred = model.predict(test[features])

r2 = r2_score(test[target], y_pred)
mape = mean_absolute_percentage_error(test[target], y_pred)
rmse = np.sqrt(mean_squared_error(test[target], y_pred))
mae = mean_absolute_error(test[target], y_pred)

print("Amaravati")
print(f"R2: {r2}, MAPE: {mape}, RMSE: {rmse}, MAE: {mae}")
# Out:
# Amaravati
# R2: 0.7192461467551567, MAPE: 0.18755505837830894, RMSE: 13.725026322050665, MAE: 10.974426229508195

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import mean_absolute_error

df = pd.read_csv("filtered_city_data.csv")
city_data = df[df['City'] == 'Delhi']

features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
target = 'AQI'

train, test = train_test_split(city_data, test_size=0.2, shuffle=False)

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(train[features], train[target])

y_pred = model.predict(test[features])

r2 = r2_score(test[target], y_pred)
mape = mean_absolute_percentage_error(test[target], y_pred)
rmse = np.sqrt(mean_squared_error(test[target], y_pred))
mae = mean_absolute_error(test[target], y_pred)

print("Delhi")
print(f"R2: {r2}, MAPE: {mape}, RMSE: {rmse}, MAE: {mae}")
# Out:
# Delhi
# R2: 0.9232925699947896, MAPE: 0.12402829012207447, RMSE: 25.429550288372234, MAE: 19.48737704918033

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import mean_absolute_error

df = pd.read_csv("filtered_city_data.csv")
city_data = df[df['City'] == 'Hyderabad']

features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
target = 'AQI'

train, test = train_test_split(city_data, test_size=0.2, shuffle=False)

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(train[features], train[target])

y_pred = model.predict(test[features])

r2 = r2_score(test[target], y_pred)
mape = mean_absolute_percentage_error(test[target], y_pred)
rmse = np.sqrt(mean_squared_error(test[target], y_pred))
mae = mean_absolute_error(test[target], y_pred)

print("Hyderabad")
print(f"R2: {r2}, MAPE: {mape}, RMSE: {rmse}, MAE: {mae}")
# Out:
# Hyderabad
# R2: 0.8610767723346189, MAPE: 0.1161812213094346, RMSE: 9.818756251019774, MAE: 7.783879781420766

# %% [markdown]
# **Gradient Boosting Regressor**

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import mean_absolute_error

df = pd.read_csv("filtered_city_data.csv")
city_data = df[df['City'] == 'Amaravati']

features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
target = 'AQI'

train, test = train_test_split(city_data, test_size=0.2, shuffle=False)

model = GradientBoostingRegressor(n_estimators=100, random_state=42)
model.fit(train[features], train[target])

y_pred = model.predict(test[features])

r2 = r2_score(test[target], y_pred)
mape = mean_absolute_percentage_error(test[target], y_pred)
rmse = np.sqrt(mean_squared_error(test[target], y_pred))
mae = mean_absolute_error(test[target], y_pred)

print(f"R2: {r2}, MAPE: {mape}, RMSE: {rmse}, MAE: {mae}")

plt.plot(test['Date'], test[target], label='Actual')
plt.plot(test['Date'], y_pred, color='red', label='Predicted')
plt.title('Mô hình dự đoán chi số chất lượng không khí AQI thành phố Amaravati')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.legend()
plt.gcf().autofmt_xdate()
plt.xticks(test['Date'][::7], rotation=45)
plt.show()
# Out:
# R2: 0.7591111379014657, MAPE: 0.1738011965085366, RMSE: 12.713311358823217, MAE: 10.095419341426236

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import mean_absolute_error

df = pd.read_csv("filtered_city_data.csv")
city_data = df[df['City'] == 'Delhi']

features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
target = 'AQI'

train, test = train_test_split(city_data, test_size=0.2, shuffle=False)

model = GradientBoostingRegressor(n_estimators=100, random_state=42)
model.fit(train[features], train[target])

y_pred = model.predict(test[features])

r2 = r2_score(test[target], y_pred)
mape = mean_absolute_percentage_error(test[target], y_pred)
rmse = np.sqrt(mean_squared_error(test[target], y_pred))
mae = mean_absolute_error(test[target], y_pred)

print(f"R2: {r2}, MAPE: {mape}, RMSE: {rmse}, MAE: {mae}")

plt.plot(test['Date'], test[target], label='Actual')
plt.plot(test['Date'], y_pred, color='red', label='Predicted')
plt.title('Mô hình dự đoán chỉ số chất lượng không khí AQI thành phố Delhi')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.legend()
plt.gcf().autofmt_xdate()
plt.xticks(test['Date'][::7], rotation=45)
plt.show()
# Out:
# R2: 0.9236314410018788, MAPE: 0.1278028577170904, RMSE: 25.373317954586145, MAE: 19.540780729800606

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import mean_absolute_error

df = pd.read_csv("filtered_city_data.csv")
city_data = df[df['City'] == 'Hyderabad']

features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
target = 'AQI'

train, test = train_test_split(city_data, test_size=0.2, shuffle=False)

model = GradientBoostingRegressor(n_estimators=100, random_state=42)
model.fit(train[features], train[target])

y_pred = model.predict(test[features])

r2 = r2_score(test[target], y_pred)
mape = mean_absolute_percentage_error(test[target], y_pred)
rmse = np.sqrt(mean_squared_error(test[target], y_pred))
mae = mean_absolute_error(test[target], y_pred)

print(f"R2: {r2}, MAPE: {mape}, RMSE: {rmse}, MAE: {mae}")

plt.plot(test['Date'], test[target], label='Actual')
plt.plot(test['Date'], y_pred, color='red', label='Predicted')
plt.title('Mô hình dự đoán chỉ số chất lượng không khí AQI thành phố Hyderabad')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.legend()
plt.gcf().autofmt_xdate()
plt.xticks(test['Date'][::7], rotation=45)
plt.show()
# Out:
# R2: 0.8481982894005561, MAPE: 0.12024256184053554, RMSE: 10.263781054667025, MAE: 8.208114566475455

# %% [markdown]
# 4b. Lựa chọn tính năng và phân tích mối tương quan

# %%
file_path = 'https://raw.githubusercontent.com/PhwTha00/btl/main/delhi.csv'
data1 = pd.read_csv(file_path)
print(data1)
# Out:
#       name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0    Delhi  2018-01-01     20.0      6.0  12.5          20.0           6.0
# 1    Delhi  2018-01-02     17.4      8.0  11.8          17.4           6.8
# 2    Delhi  2018-01-03     17.2      8.0  11.1          17.2           6.0
# 3    Delhi  2018-01-04     20.2      5.0  10.9          20.2           3.3
# 4    Delhi  2018-01-05     19.0      7.4  11.7          19.0           6.2
# ..     ...         ...      ...      ...   ...           ...           ...
# 907  Delhi  2020-06-26     36.8     29.0  32.3          48.0          34.5
# 908  Delhi  2020-06-27     40.0     29.8  34.0          51.0          34.1
# 909  Delhi  2020-06-28     40.2     30.5  36.2          52.7          36.5
# 910  Delhi  2020-06-29     40.8     28.5  35.1          49.6          31.3
# 911  Delhi  2020-06-30     37.0     27.3  32.2          52.5          30.6
#
# ...

# %%
city_data = pd.read_csv('filtered_city_data.csv')
delhi_data = city_data[city_data['City'] == 'Delhi'].copy()

delhi_data['Date'] = pd.to_datetime(delhi_data['Date'])
selected_weather_features = ['datetime', 'tempmax', 'tempmin', 'feelslikemax', 'feelslikemin', 'humidity', 'windspeed', 'conditions']

weather_data = pd.read_csv('https://raw.githubusercontent.com/PhwTha00/btl/main/delhi.csv')

selected_weather_data = weather_data[selected_weather_features].copy()
selected_weather_data['datetime'] = pd.to_datetime(selected_weather_data['datetime'])

merged_data = pd.merge(delhi_data[['Date', 'AQI']], selected_weather_data, left_on='Date', right_on='datetime')
print(merged_data)
# Out:
#           Date    AQI   datetime  tempmax  tempmin  feelslikemax  \
# 0   2018-01-01  462.0 2018-01-01     20.0      6.0          20.0
# 1   2018-01-02  439.0 2018-01-02     17.4      8.0          17.4
# 2   2018-01-03  405.0 2018-01-03     17.2      8.0          17.2
# 3   2018-01-04  394.0 2018-01-04     20.2      5.0          20.2
# 4   2018-01-05  398.0 2018-01-05     19.0      7.4          19.0
# ..         ...    ...        ...      ...      ...           ...
# 907 2020-06-26  104.0 2020-06-26     36.8     29.0          48.0
# 908 2020-06-27  112.0 2020-06-27     40.0     29.8          51.0
# 909 2020-06-28  196.0 2020-06-28     40.2     30.5          52.7
# 910 2020-06-29  233.0 2020-06-29     40.8     28.5          49.6
# 911 2020-06-30  114.0 2020-06-30     37.0     27.3          52.5
#
#      feelslikemin  humidity  windspeed              conditions
# 0             6.0      82.5        9.4                   Clear
# ...

# %%
import seaborn as sns
selected_features = ['tempmax', 'tempmin', 'feelslikemax', 'feelslikemin', 'humidity', 'windspeed', 'AQI']
selected_data = merged_data[selected_features]

correlation_matrix = selected_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Ma trận tương quan giữa các yếu tố Delhi')
plt.show()

# %%
file_path = 'https://raw.githubusercontent.com/PhwTha00/btl/main/hyderabad.csv'
data2 = pd.read_csv(file_path)
print(data2)
# Out:
#                 name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0    Hyderabad,India  2018-01-01     29.9     14.0  22.1          29.2
# 1    Hyderabad,India  2018-01-02     28.9     16.1  22.4          29.2
# 2    Hyderabad,India  2018-01-03     28.8     17.0  22.1          28.4
# 3    Hyderabad,India  2018-01-04     28.4     15.1  21.5          27.8
# 4    Hyderabad,India  2018-01-05     27.9     13.1  20.7          27.3
# ..               ...         ...      ...      ...   ...           ...
# 907  Hyderabad,India  2020-06-26     33.3     24.0  28.7          38.3
# 908  Hyderabad,India  2020-06-27     34.7     22.8  28.3          42.1
# 909  Hyderabad,India  2020-06-28     32.2     23.2  26.2          37.2
# 910  Hyderabad,India  2020-06-29     31.0     23.7  26.3          37.9
# 911  Hyderabad,India  2020-06-30     31.8     24.0  27.1          39.2
#
#      feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# ...

# %%
city_data = pd.read_csv('filtered_city_data.csv')
hyderabad_data = city_data[city_data['City'] == 'Hyderabad'].copy()
hyderabad_data['Date'] = pd.to_datetime(delhi_data['Date'])

selected_weather_features1 = ['datetime', 'tempmax', 'tempmin', 'feelslikemax', 'feelslikemin', 'humidity', 'windspeed', 'conditions']
weather_data1 = pd.read_csv('https://raw.githubusercontent.com/PhwTha00/btl/main/hyderabad.csv')

selected_weather_data1 = weather_data[selected_weather_features].copy()

selected_weather_data1['datetime'] = pd.to_datetime(selected_weather_data['datetime'])

merged_data1 = pd.merge(delhi_data[['Date', 'AQI']], selected_weather_data, left_on='Date', right_on='datetime')
print(merged_data1)
# Out:
#           Date    AQI   datetime  tempmax  tempmin  feelslikemax  \
# 0   2018-01-01  462.0 2018-01-01     20.0      6.0          20.0
# 1   2018-01-02  439.0 2018-01-02     17.4      8.0          17.4
# 2   2018-01-03  405.0 2018-01-03     17.2      8.0          17.2
# 3   2018-01-04  394.0 2018-01-04     20.2      5.0          20.2
# 4   2018-01-05  398.0 2018-01-05     19.0      7.4          19.0
# ..         ...    ...        ...      ...      ...           ...
# 907 2020-06-26  104.0 2020-06-26     36.8     29.0          48.0
# 908 2020-06-27  112.0 2020-06-27     40.0     29.8          51.0
# 909 2020-06-28  196.0 2020-06-28     40.2     30.5          52.7
# 910 2020-06-29  233.0 2020-06-29     40.8     28.5          49.6
# 911 2020-06-30  114.0 2020-06-30     37.0     27.3          52.5
#
#      feelslikemin  humidity  windspeed              conditions
# 0             6.0      82.5        9.4                   Clear
# ...

# %%
import seaborn as sns
selected_features1 = ['tempmax', 'tempmin', 'feelslikemax', 'feelslikemin', 'humidity', 'windspeed', 'AQI']
selected_data1 = merged_data[selected_features]

correlation_matrix = selected_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Ma trận tương quan giữa các yếu tố Hyderabad')
plt.show()

# %% [markdown]
# 4c. Phân loại và hồi quy

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

data = pd.read_csv('filtered_city_data.csv')

X = data[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']]
y = data['AQI_Bucket']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.8275154004106776
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.79      0.70      0.75        44
#     Moderate       0.85      0.88      0.86       169
#         Poor       0.69      0.81      0.75        47
# Satisfactory       0.84      0.84      0.84       168
#       Severe       0.92      0.80      0.86        15
#    Very Poor       0.89      0.75      0.81        44
#
#     accuracy                           0.83       487
#    macro avg       0.83      0.80      0.81       487
# weighted avg       0.83      0.83      0.83       487

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

X_reg = data[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']]
y_reg = data['AQI']

X_reg_scaled = scaler.fit_transform(X_reg)

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg_scaled, y_reg, test_size=0.2, random_state=42)

reg_model = LinearRegression()
reg_model.fit(X_train_reg, y_train_reg)

y_pred_reg = reg_model.predict(X_test_reg)

mse = mean_squared_error(y_test_reg, y_pred_reg)
r2 = r2_score(y_test_reg, y_pred_reg)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 570.417201039578
# R-squared: 0.9467430399709199
